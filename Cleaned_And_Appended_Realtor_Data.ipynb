# %%
import pandas as pd

# %%
import requests

url = "https://realtor-com-real-estate.p.rapidapi.com/for-sale"

querystring = {"city":"Nashville","state_code":"TN","limit":"400","offset":"0", "home_size_max":"750"}

querystring1 = {"city":"Nashville","state_code":"TN","limit":"400","offset":"0", "home_size_min":"750", "home_size_max":"1000"}

querystring2 = {"city":"Nashville","state_code":"TN","limit":"400","offset":"0", "home_size_min":"1250", "home_size_max":"1500"}

querystring3 = {"city":"Nashville","state_code":"TN","limit":"400","offset":"0", "home_size_min":"1500", "home_size_max":"1750"}

querystring4 = {"city":"Nashville","state_code":"TN","limit":"400","offset":"0", "home_size_min":"1750", "home_size_max":"2000"}

querystring5 = {"city":"Nashville","state_code":"TN","limit":"400","offset":"0", "home_size_min":"2000", "home_size_max":"2250"}

querystring6 = {"city":"Nashville","state_code":"TN","limit":"400","offset":"0", "home_size_min":"2250", "home_size_max":"2500"}

querystring7 = {"city":"Nashville","state_code":"TN","limit":"400","offset":"0", "home_size_min":"2500", "home_size_max":"2750"}

querystring8 = {"city":"Nashville","state_code":"TN","limit":"400","offset":"0", "home_size_min":"2750", "home_size_max":"3000"}

querystring9 = {"city":"Nashville","state_code":"TN","limit":"400","offset":"0", "home_size_min":"3000", "home_size_max":"3250"}

querystring10= {"city":"Nashville","state_code":"TN","limit":"400","offset":"0", "home_size_min":"3250", "home_size_max":"3500"}

querystring11= {"city":"Nashville","state_code":"TN","limit":"400","offset":"0", "home_size_min":"3500", "home_size_max":"3750"}

querystring12= {"city":"Nashville","state_code":"TN","limit":"400","offset":"0", "home_size_min":"3750"}



headers = {
    'x-rapidapi-key': "KEY REMOVED",
    'x-rapidapi-host': "realtor-com-real-estate.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

response1 = requests.request("GET", url, headers=headers, params=querystring1)

response2 = requests.request("GET", url, headers=headers, params=querystring2)
response3 = requests.request("GET", url, headers=headers, params=querystring3)
response4 = requests.request("GET", url, headers=headers, params=querystring4)
response5 = requests.request("GET", url, headers=headers, params=querystring5)
response6 = requests.request("GET", url, headers=headers, params=querystring6)
response7 = requests.request("GET", url, headers=headers, params=querystring7)
response8 = requests.request("GET", url, headers=headers, params=querystring8)
response9 = requests.request("GET", url, headers=headers, params=querystring9)
response10 = requests.request("GET", url, headers=headers, params=querystring10)
response11 = requests.request("GET", url, headers=headers, params=querystring11)
response12 = requests.request("GET", url, headers=headers, params=querystring12)

# %%
df1 = pd.json_normalize(response1.json()['data'], record_path="results", max_level = 7)
df2 = pd.json_normalize(response2.json()['data'], record_path="results", max_level = 7)
df3 = pd.json_normalize(response3.json()['data'], record_path="results", max_level = 7)
df4 = pd.json_normalize(response4.json()['data'], record_path="results", max_level = 7)
df5 = pd.json_normalize(response5.json()['data'], record_path="results", max_level = 7)
df6 = pd.json_normalize(response6.json()['data'], record_path="results", max_level = 7)
df7 = pd.json_normalize(response7.json()['data'], record_path="results", max_level = 7)
df8 = pd.json_normalize(response8.json()['data'], record_path="results", max_level = 7)
df9 = pd.json_normalize(response9.json()['data'], record_path="results", max_level = 7)
df10 = pd.json_normalize(response10.json()['data'], record_path="results", max_level = 7)
df11 = pd.json_normalize(response11.json()['data'], record_path="results", max_level = 7)
df12 = pd.json_normalize(response12.json()['data'], record_path="results", max_level = 7)

# %%
print(df1['listing_id'].count())
print(df2['listing_id'].count())
print(df3['listing_id'].count())
print(df4['listing_id'].count())
print(df5['listing_id'].count())
print(df6['listing_id'].count())
print(df7['listing_id'].count())
print(df8['listing_id'].count())
print(df9['listing_id'].count())
print(df10['listing_id'].count())
print(df11['listing_id'].count())
print(df12['listing_id'].count())
# Out:
# 159
# 199
# 197
# 194
# 195
# 129
# 93
# 60
# 56
# 41
# 40
# 153

# %%
df1['listing_id'].count()+ df2['listing_id'].count() + df3['listing_id'].count()+\
df4['listing_id'].count()+df5['listing_id'].count()+ df6['listing_id'].count() + \
df7['listing_id'].count()+df8['listing_id'].count()+df9['listing_id'].count()+ \
df10['listing_id'].count()+ df11['listing_id'].count()+ df12['listing_id'].count()
# Out:
# 1516

# %%
list_of_df = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12]
df = pd.DataFrame()
for x in list_of_df:
    df = df.append(x)

# %%
print(df.photos)
# Out:
# 0      [{'tags': [{'label': 'road_view', 'probability...
# 1      [{'tags': [{'label': 'porch_yard', 'probabilit...
# 2      [{'tags': [{'label': 'porch_yard', 'probabilit...
# 3      [{'tags': [{'label': 'kitchen', 'probability':...
# 4      [{'tags': [{'label': 'house_view', 'probabilit...
#                              ...
# 148    [{'tags': [{'label': 'house_view', 'probabilit...
# 149    [{'tags': [{'label': 'house_view', 'probabilit...
# 150    [{'tags': [{'label': 'kitchen', 'probability':...
# 151    [{'tags': [{'label': 'farm_land', 'probability...
# 152    [{'tags': [{'label': 'porch_yard', 'probabilit...
# Name: photos, Length: 1539, dtype: object

# %%
# Out:
# {'total': 159,
#  'count': 159,
#  'results': [{'primary_photo': {'href': 'https://ap.rdcpix.com/ea72f56732072f91ea72a2c7fd61e584l-m3586448538s-w1024_h768.jpg'},
#    'last_update_date': '2020-12-16T12:09:41Z',
#    'source': {'plan_id': None,
#     'agents': [{'office_name': None}],
#     'spec_id': None,
#     'type': 'mls'},
#    'tags': ['central_air', 'central_heat', 'single_story', 'garage_1_or_more'],
#    'permalink': '2315-Whites-Creek-Pike_Nashville_TN_37207_M89278-42262',
#    'status': 'for_sale',
#    'list_date': '2020-06-16T10:50:34Z',
#    'open_houses': None,
#    'description': {'baths_3qtr': None,
#     'year_built': 1950,
#     'sold_price': None,
#     'baths_full': 1,
#     'name': None,
#     'baths_half': None,
#     'lot_sqft': 7841,
#     'sqft': 840,
#     'baths': 1,
#     'sub_type': None,
#     'baths_1qtr': None,
#     'garage': 1,
#     'stories': 1,
#     'beds': 1,
#     'type': 'single_family'},
#    'branding': [{'name': 'Green Property Brokers, Inc.',
#      'photo': None,
#      'type': 'Office'}],
#    'list_price': 125000,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '8927842262',
#    'photos': [{'tags': [{'label': 'road_view',
#        'probability': 0.99844723939896},
#       {'label': 'farm_land', 'probability': 0.0013534695608541},
#       {'label': 'porch', 'probability': 7.5650241342373e-05}],
#      'href': 'https://ap.rdcpix.com/ea72f56732072f91ea72a2c7fd61e584l-m3586448538s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': None,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': True,
#     'is_price_reduced': None,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': False},
#    'community': None,
#    'products': {'brand_name': 'basic_opt_in'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2917343587',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True}]},
#    'listing_id': '2917343587',
#    'price_reduced_amount': None,
#    'location': {'address': {'postal_code': '37207',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.7957, 'lat': 36.209869},
#      'city': 'Nashville',
#      'state_code': 'TN',
#      'line': '2315 Whites Creek Pike'},
#     'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=2315%20Whites%20Creek%20Pike%2C%20Nashville%2C%20TN%2037207&size=640x480&source=outdoor&signature=-eRVzkYMydCnMdy4c9Nwg-7LTpk=',
#     'county': {'fips_code': '47037', 'name': 'Davidson'}},
#    'matterport': False},
#   {'primary_photo': {'href': 'https://ap.rdcpix.com/620ee0c187d979005c0e192c16c65992l-m1097802782s-w1024_h768.jpg'},
#    'last_update_date': '2021-03-31T13:48:29Z',
#    'source': {'plan_id': None,
#     'agents': [{'office_name': 'Hodges and Fooshee Realty Inc.'}],
#     'spec_id': None,
#     'type': 'mls'},
#    'tags': ['single_story', 'rental_property'],
#    'permalink': '1807-10th-Ave-N_Nashville_TN_37208_M74535-63791',
#    'status': 'for_sale',
#    'list_date': '2020-10-17T03:38:58Z',
#    'open_houses': None,
#    'description': {'baths_3qtr': None,
#     'year_built': 1945,
#     'sold_price': None,
#     'baths_full': 1,
#     'name': None,
#     'baths_half': None,
#     'lot_sqft': 6098,
#     'sqft': 825,
#     'baths': 1,
#     'sub_type': None,
#     'baths_1qtr': None,
#     'garage': None,
#     'stories': 1,
#     'beds': 2,
#     'type': 'single_family'},
#    'branding': [{'name': 'Hodges and Fooshee Realty Inc.',
#      'photo': None,
#      'type': 'Office'}],
#    'list_price': 240000,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '7453563791',
#    'photos': [{'tags': [{'label': 'porch_yard',
#        'probability': 0.96811020374298},
#       {'label': 'yard', 'probability': 0.022770864889026},
#       {'label': 'porch', 'probability': 0.0062115592882037}],
#      'href': 'https://ap.rdcpix.com/620ee0c187d979005c0e192c16c65992l-m1097802782s-w1024_h768.jpg'},
#     {'tags': [{'label': 'house_view', 'probability': 0.68523818254471},
#       {'label': 'yard', 'probability': 0.21907220780849},
#       {'label': 'porch_yard', 'probability': 0.094911701977253}],
#      'href': 'https://ap.rdcpix.com/620ee0c187d979005c0e192c16c65992l-m3450407839s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.66193509101868},
#       {'label': 'unknown', 'probability': 0.29474610090256},
#       {'label': 'bedroom', 'probability': 0.030896365642548}],
#      'href': 'https://ap.rdcpix.com/620ee0c187d979005c0e192c16c65992l-m199090071s-w1024_h768.jpg'},
#     {'tags': [{'label': 'unknown', 'probability': 0.87501859664917},
#       {'label': 'living_room', 'probability': 0.10316991060972},
#       {'label': 'dining_room', 'probability': 0.012520126067102}],
#      'href': 'https://ap.rdcpix.com/620ee0c187d979005c0e192c16c65992l-m1553672547s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.56355857849121},
#       {'label': 'unknown', 'probability': 0.32991516590118},
#       {'label': 'bedroom', 'probability': 0.078496232628822}],
#      'href': 'https://ap.rdcpix.com/620ee0c187d979005c0e192c16c65992l-m1056459705s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': None,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': True,
#     'is_price_reduced': False,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': False},
#    'community': None,
#    'products': {'brand_name': 'basic_opt_in'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2922532514',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True},
#      {'listing_id': '642263099',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None}]},
#    'listing_id': '2922532514',
#    'price_reduced_amount': 10000,
#    'location': {'address': {'postal_code': '37208',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.803597, 'lat': 36.180973},
#      'city': 'Nashville',
#      'state_code': 'TN',
#      'line': '1807 10th Ave N'},
#     'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1807%2010th%20Ave%20N%2C%20Nashville%2C%20TN%2037208&size=640x480&source=outdoor&signature=PwUvL6wSTdcmUKmzfw3TedOJuqg=',
#     'county': {'fips_code': '47037', 'name': 'Davidson'}},
#    'matterport': False},
#   {'primary_photo': {'href': 'https://ap.rdcpix.com/d6b6fae93a3428a81900c9c04baed21bl-m48447517s-w1024_h768.jpg'},
#    'last_update_date': '2021-05-04T10:37:52Z',
#    'source': {'plan_id': None,
#     'agents': [{'office_name': None}],
#     'spec_id': None,
#     'type': 'mls'},
#    'tags': ['central_air',
#     'central_heat',
#     'community_outdoor_space',
#     'dishwasher',
#     'hardwood_floors',
#     'view',
#     'single_story',
#     'updated_kitchen',
#     'big_lot',
#     'lake'],
#    'permalink': '4603-Grays-Point-Rd_Joelton_TN_37080_M86753-55872',
#    'status': 'for_sale',
#    'list_date': '2021-05-04T16:05:59Z',
#    'open_houses': None,
#    'description': {'baths_3qtr': None,
#     'year_built': 1958,
#     'sold_price': 179900,
#     'baths_full': 1,
#     'name': None,
#     'baths_half': None,
#     'lot_sqft': 217800,
#     'sqft': 900,
#     'baths': 1,
#     'sub_type': None,
#     'baths_1qtr': None,
#     'garage': None,
#     'stories': 1,
#     'beds': 2,
#     'type': 'single_family'},
#    'branding': [{'name': 'EXIT REALTY CLARK & COMPANY',
#      'photo': 'https://ap.rdcpix.com/30271f8ae7c83f0921da125e798ac4e7o-b1637540070s.jpg',
#      'type': 'Office'}],
#    'list_price': 274900,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '8675355872',
#    'photos': [{'tags': [{'label': 'porch_yard',
#        'probability': 0.99447953701019},
#       {'label': 'porch', 'probability': 0.0031804395839572},
#       {'label': 'yard', 'probability': 0.0021164736244828}],
#      'href': 'https://ap.rdcpix.com/d6b6fae93a3428a81900c9c04baed21bl-m48447517s-w1024_h768.jpg'},
#     {'tags': [{'label': 'yard', 'probability': 0.88375616073608},
#       {'label': 'porch_yard', 'probability': 0.056792452931404},
#       {'label': 'farm_land', 'probability': 0.055705886334181}],
#      'href': 'https://ap.rdcpix.com/d6b6fae93a3428a81900c9c04baed21bl-m3825262721s-w1024_h768.jpg'},
#     {'tags': [{'label': 'kitchen', 'probability': 0.9547592997551},
#       {'label': 'laundry_room', 'probability': 0.044987712055445},
#       {'label': 'house_view', 'probability': 8.986187458504e-05}],
#      'href': 'https://ap.rdcpix.com/d6b6fae93a3428a81900c9c04baed21bl-m734627154s-w1024_h768.jpg'},
#     {'tags': [{'label': 'kitchen', 'probability': 0.99469119310379},
#       {'label': 'laundry_room', 'probability': 0.0022081630304456},
#       {'label': 'house_view', 'probability': 0.0013059739721939}],
#      'href': 'https://ap.rdcpix.com/d6b6fae93a3428a81900c9c04baed21bl-m207164081s-w1024_h768.jpg'},
#     {'tags': [{'label': 'kitchen', 'probability': 0.99706548452377},
#       {'label': 'laundry_room', 'probability': 0.0025466517545283},
#       {'label': 'dining_room', 'probability': 6.7515793489292e-05}],
#      'href': 'https://ap.rdcpix.com/d6b6fae93a3428a81900c9c04baed21bl-m4278277883s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': None,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': None,
#     'is_price_reduced': None,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': True},
#    'community': None,
#    'products': {'brand_name': 'advantage_brand'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2928892552',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True},
#      {'listing_id': '624106779',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '622557311',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None}]},
#    'listing_id': '2928892552',
#    'price_reduced_amount': None,
#    'location': {'address': {'postal_code': '37080',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.919894, 'lat': 36.285676},
#      'city': 'Joelton',
#      'state_code': 'TN',
#      'line': '4603 Grays Point Rd'},
#     'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=4603%20Grays%20Point%20Rd%2C%20Joelton%2C%20TN%2037080&size=640x480&source=outdoor&signature=D9vPmyl3WzC_BMJKNk5scCHclVI=',
#     'county': {'fips_code': '47037', 'name': 'Davidson'}},
#    'matterport': False},
#   {'primary_photo': {'href': 'https://ap.rdcpix.com/4f6a7d1eb3af03aca864a2c186d5d456l-m367699106s-w1024_h768.jpg'},
#    'last_update_date': '2021-04-20T19:59:27Z',
#    'source': {'plan_id': None,
#     'agents': [{'office_name': None}],
#     'spec_id': None,
#     'type': 'mls'},
#    'tags': ['central_air',
#     'central_heat',
#     'dishwasher',
#     'single_story',
#     'updated_kitchen'],
#    'permalink': '1533B-B-12th-Ave-N_Nashville_TN_37208_M77640-69217',
#    'status': 'for_sale',
#    'list_date': '2021-02-23T21:35:37Z',
#    'open_houses': None,
#    'description': {'baths_3qtr': None,
#     'year_built': 1925,
#     'sold_price': None,
#     'baths_full': 1,
#     'name': None,
#     'baths_half': None,
#     'lot_sqft': 3049,
#     'sqft': 757,
#     'baths': 1,
#     'sub_type': None,
#     'baths_1qtr': None,
#     'garage': None,
#     'stories': 1,
#     'beds': 2,
#     'type': 'single_family'},
#    'branding': [{'name': 'Everything Real Estate',
#      'photo': None,
#      'type': 'Office'}],
#    'list_price': 249900,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '7764069217',
#    'photos': [{'tags': [{'label': 'kitchen', 'probability': 0.99952149391174},
#       {'label': 'unknown', 'probability': 0.00031395911355503},
#       {'label': 'laundry_room', 'probability': 0.00010123522952199}],
#      'href': 'https://ap.rdcpix.com/4f6a7d1eb3af03aca864a2c186d5d456l-m367699106s-w1024_h768.jpg'},
#     {'tags': [{'label': 'kitchen', 'probability': 0.99937528371811},
#       {'label': 'laundry_room', 'probability': 0.00061851000646129},
#       {'label': 'house_view', 'probability': 5.3557496357826e-06}],
#      'href': 'https://ap.rdcpix.com/4f6a7d1eb3af03aca864a2c186d5d456l-m1184031205s-w1024_h768.jpg'},
#     {'tags': [{'label': 'kitchen', 'probability': 0.99871098995209},
#       {'label': 'laundry_room', 'probability': 0.0010773238027468},
#       {'label': 'dining_room', 'probability': 0.0001082154631149}],
#      'href': 'https://ap.rdcpix.com/4f6a7d1eb3af03aca864a2c186d5d456l-m3971455605s-w1024_h768.jpg'},
#     {'tags': [{'label': 'bathroom', 'probability': 0.99975663423538},
#       {'label': 'floor_plan', 'probability': 8.2988080976065e-05},
#       {'label': 'unknown', 'probability': 4.5850960304961e-05}],
#      'href': 'https://ap.rdcpix.com/4f6a7d1eb3af03aca864a2c186d5d456l-m2200430860s-w1024_h768.jpg'},
#     {'tags': [{'label': 'bathroom', 'probability': 0.99995636940002},
#       {'label': 'unknown', 'probability': 4.0602430090075e-05},
#       {'label': 'bedroom', 'probability': 2.3143338694354e-06}],
#      'href': 'https://ap.rdcpix.com/4f6a7d1eb3af03aca864a2c186d5d456l-m3756508521s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': None,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': True,
#     'is_price_reduced': None,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': False},
#    'community': None,
#    'products': {'brand_name': 'basic_opt_in'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2926295785',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True},
#      {'listing_id': '2928408307',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '2921692321',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '2913211532',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '2786158126',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '624878963',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '618034555',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None}]},
#    'listing_id': '2926295785',
#    'price_reduced_amount': None,
#    'location': {'address': {'postal_code': '37208',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.802987, 'lat': 36.175771},
#      'city': 'Nashville',
#      'state_code': 'TN',
#      'line': '1533B 12th Ave N'},
#     'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1533B%2012th%20Ave%20N%2C%20Nashville%2C%20TN%2037208&size=640x480&source=outdoor&signature=7KMcyuNmSGc8nb31vBO-0-m_zZA=',
#     'county': {'fips_code': '47037', 'name': 'Davidson'}},
#    'matterport': False},
#   {'primary_photo': {'href': 'https://ap.rdcpix.com/c27e959c3f1fd1960a1f8ecede61460bl-m383927178s-w1024_h768.jpg'},
#    'last_update_date': '2021-05-03T11:37:09Z',
#    'source': {'plan_id': None,
#     'agents': [{'office_name': None}],
#     'spec_id': None,
#     'type': 'mls'},
#    'tags': ['central_air',
#     'community_outdoor_space',
#     'hardwood_floors',
#     'basement',
#     'single_story',
#     'updated_kitchen',
#     'big_yard',
#     'fenced_yard'],
#    'permalink': '913-W-Eastland-Ave_Nashville_TN_37206_M71878-19652',
#    'status': 'for_sale',
#    'list_date': '2021-05-03T16:35:32Z',
#    'open_houses': None,
#    'description': {'baths_3qtr': None,
#     'year_built': 1935,
#     'sold_price': 175000,
#     'baths_full': 1,
#     'name': None,
#     'baths_half': None,
#     'lot_sqft': 6098,
#     'sqft': 806,
#     'baths': 1,
#     'sub_type': None,
#     'baths_1qtr': None,
#     'garage': None,
#     'stories': 1,
#     'beds': 2,
#     'type': 'single_family'},
#    'branding': [{'name': 'Compass Tennessee, LLC dba Compass RE',
#      'photo': None,
#      'type': 'Office'}],
#    'list_price': 310000,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '7187819652',
#    'photos': [{'tags': [{'label': 'house_view',
#        'probability': 0.98554438352585},
#       {'label': 'porch_yard', 'probability': 0.011310102418065},
#       {'label': 'yard', 'probability': 0.0023108590394258}],
#      'href': 'https://ap.rdcpix.com/c27e959c3f1fd1960a1f8ecede61460bl-m383927178s-w1024_h768.jpg'},
#     {'tags': [{'label': 'house_view', 'probability': 0.80075043439865},
#       {'label': 'yard', 'probability': 0.17337991297245},
#       {'label': 'porch_yard', 'probability': 0.014778704382479}],
#      'href': 'https://ap.rdcpix.com/c27e959c3f1fd1960a1f8ecede61460bl-m2220997429s-w1024_h768.jpg'},
#     {'tags': [{'label': 'house_view', 'probability': 0.99929058551788},
#       {'label': 'porch_yard', 'probability': 0.00055702787358314},
#       {'label': 'farm_land', 'probability': 9.2848073109053e-05}],
#      'href': 'https://ap.rdcpix.com/c27e959c3f1fd1960a1f8ecede61460bl-m716420382s-w1024_h768.jpg'},
#     {'tags': [{'label': 'porch', 'probability': 0.99675577878952},
#       {'label': 'porch_yard', 'probability': 0.0032309687230736},
#       {'label': 'road_view', 'probability': 1.2116629477532e-05}],
#      'href': 'https://ap.rdcpix.com/c27e959c3f1fd1960a1f8ecede61460bl-m2872133973s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.99152886867523},
#       {'label': 'house_view', 'probability': 0.0046194260939956},
#       {'label': 'unknown', 'probability': 0.0028481835033745}],
#      'href': 'https://ap.rdcpix.com/c27e959c3f1fd1960a1f8ecede61460bl-m823148341s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': None,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': True,
#     'is_price_reduced': None,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': True},
#    'community': None,
#    'products': {'brand_name': 'essentials'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2928856065',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True},
#      {'listing_id': '2722297356',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '2687365244',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '578828191',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None}]},
#    'listing_id': '2928856065',
#    'price_reduced_amount': None,
#    'location': {'address': {'postal_code': '37206',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.756618, 'lat': 36.185397},
#      'city': 'Nashville',
#      'state_code': 'TN',
#      'line': '913 W Eastland Ave'},
#     'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=913%20W%20Eastland%20Ave%2C%20Nashville%2C%20TN%2037206&size=640x480&source=outdoor&signature=63e68edQT9SuV9zMsl_-Qk1vbhs=',
#     'county': {'fips_code': '47037', 'name': 'Davidson'}},
#    'matterport': False},
#   {'primary_photo': {'href': 'https://ap.rdcpix.com/fd3c9cc9c8eb0f1e3dc5b5a854ceb1b6l-m4055415216s-w1024_h768.jpg'},
#    'last_update_date': '2021-04-28T13:08:54Z',
#    'source': {'plan_id': None,
#     'agents': [{'office_name': None}],
#     'spec_id': None,
#     'type': 'mls'},
#    'tags': ['central_air',
#     'central_heat',
#     'community_outdoor_space',
#     'hardwood_floors',
#     'washer_dryer',
#     'single_story',
#     'updated_kitchen',
#     'fenced_yard',
#     'big_lot'],
#    'permalink': '926-Marilyn-Rd_Nashville_TN_37209_M73874-41934',
#    'status': 'for_sale',
#    'list_date': '2021-02-08T15:34:26Z',
#    'open_houses': None,
#    'description': {'baths_3qtr': None,
#     'year_built': 1954,
#     'sold_price': 175000,
#     'baths_full': 1,
#     'name': None,
#     'baths_half': None,
#     'lot_sqft': 8712,
#     'sqft': 750,
#     'baths': 1,
#     'sub_type': None,
#     'baths_1qtr': None,
#     'garage': None,
#     'stories': 1,
#     'beds': 2,
#     'type': 'single_family'},
#    'branding': [{'name': 'For Sale Realty', 'photo': None, 'type': 'Office'}],
#    'list_price': 250000,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '7387441934',
#    'photos': [{'tags': [{'label': 'house_view',
#        'probability': 0.99995708465576},
#       {'label': 'porch', 'probability': 3.3428434107918e-05},
#       {'label': 'porch_yard', 'probability': 8.3169970821473e-06}],
#      'href': 'https://ap.rdcpix.com/fd3c9cc9c8eb0f1e3dc5b5a854ceb1b6l-m4055415216s-w1024_h768.jpg'},
#     {'tags': [{'label': 'unknown', 'probability': 0.92402750253677},
#       {'label': 'living_room', 'probability': 0.060105342417955},
#       {'label': 'bedroom', 'probability': 0.014836048707366}],
#      'href': 'https://ap.rdcpix.com/fd3c9cc9c8eb0f1e3dc5b5a854ceb1b6l-m2866072952s-w1024_h768.jpg'},
#     {'tags': [{'label': 'bedroom', 'probability': 0.84686058759689},
#       {'label': 'unknown', 'probability': 0.14800064265728},
#       {'label': 'living_room', 'probability': 0.0050302678719163}],
#      'href': 'https://ap.rdcpix.com/fd3c9cc9c8eb0f1e3dc5b5a854ceb1b6l-m4137782767s-w1024_h768.jpg'},
#     {'tags': [{'label': 'bedroom', 'probability': 0.63968461751938},
#       {'label': 'unknown', 'probability': 0.35324835777283},
#       {'label': 'living_room', 'probability': 0.0048961308784783}],
#      'href': 'https://ap.rdcpix.com/fd3c9cc9c8eb0f1e3dc5b5a854ceb1b6l-m1554446747s-w1024_h768.jpg'},
#     {'tags': [{'label': 'kitchen', 'probability': 0.99886298179626},
#       {'label': 'laundry_room', 'probability': 0.00081866723485291},
#       {'label': 'dining_room', 'probability': 0.00012571706611197}],
#      'href': 'https://ap.rdcpix.com/fd3c9cc9c8eb0f1e3dc5b5a854ceb1b6l-m3733713128s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': None,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': True,
#     'is_price_reduced': True,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': False},
#    'community': None,
#    'products': {'brand_name': 'basic_opt_in'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2925847411',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True},
#      {'listing_id': '2818419127',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '624214683',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '621722535',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '619190123',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None}]},
#    'listing_id': '2925847411',
#    'price_reduced_amount': 14000,
#    'location': {'address': {'postal_code': '37209',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.862719, 'lat': 36.160343},
#      'city': 'Nashville',
#      'state_code': 'TN',
#      'line': '926 Marilyn Rd'},
#     'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=926%20Marilyn%20Rd%2C%20Nashville%2C%20TN%2037209&size=640x480&source=outdoor&signature=3I8cA8ZNZMW-jozqSWJylYYbNT0=',
#     'county': {'fips_code': '47037', 'name': 'Davidson'}},
#    'matterport': False},
#   {'primary_photo': {'href': 'https://ap.rdcpix.com/82d0126dfee1241624f7e2f85242081el-m3472212502s-w1024_h768.jpg'},
#    'last_update_date': '2021-03-07T07:37:12Z',
#    'source': {'plan_id': None,
#     'agents': [{'office_name': None}],
#     'spec_id': None,
#     'type': 'mls'},
#    'tags': ['central_air',
#     'central_heat',
#     'community_outdoor_space',
#     'hardwood_floors',
#     'laundry_room',
#     'single_story',
#     'garage_1_or_more',
#     'garage_2_or_more',
#     'garage_3_or_more',
#     'modern_kitchen',
#     'white_kitchen',
#     'big_yard',
#     'fenced_yard',
#     'front_porch',
#     'open_house'],
#    'permalink': '1617-17th-Ave-N_Nashville_TN_37208_M75906-27928',
#    'status': 'for_sale',
#    'list_date': '2021-03-05T02:34:13Z',
#    'open_houses': None,
#    'description': {'baths_3qtr': None,
#     'year_built': 1945,
#     'sold_price': 280000,
#     'baths_full': 1,
#     'name': None,
#     'baths_half': None,
#     'lot_sqft': 8276,
#     'sqft': 849,
#     'baths': 1,
#     'sub_type': None,
#     'baths_1qtr': None,
#     'garage': 4,
#     'stories': 1,
#     'beds': 2,
#     'type': 'single_family'},
#    'branding': [{'name': 'Compass Tennessee, Llc',
#      'photo': None,
#      'type': 'Office'}],
#    'list_price': 275000,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '7590627928',
#    'photos': [{'tags': [{'label': 'house_view',
#        'probability': 0.86677485704422},
#       {'label': 'porch', 'probability': 0.072654880583286},
#       {'label': 'porch_yard', 'probability': 0.060329675674438}],
#      'href': 'https://ap.rdcpix.com/82d0126dfee1241624f7e2f85242081el-m3472212502s-w1024_h768.jpg'},
#     {'tags': [{'label': 'house_view', 'probability': 0.94885224103928},
#       {'label': 'porch_yard', 'probability': 0.035038914531469},
#       {'label': 'porch', 'probability': 0.015782669186592}],
#      'href': 'https://ap.rdcpix.com/82d0126dfee1241624f7e2f85242081el-m1599520508s-w1024_h768.jpg'},
#     {'tags': [{'label': 'porch', 'probability': 0.58808636665344},
#       {'label': 'porch_yard', 'probability': 0.40517383813858},
#       {'label': 'house_view', 'probability': 0.0060434057377279}],
#      'href': 'https://ap.rdcpix.com/82d0126dfee1241624f7e2f85242081el-m2702522025s-w1024_h768.jpg'},
#     {'tags': [{'label': 'yard', 'probability': 0.98659801483154},
#       {'label': 'porch_yard', 'probability': 0.0094427326694131},
#       {'label': 'farm_land', 'probability': 0.0024662078358233}],
#      'href': 'https://ap.rdcpix.com/82d0126dfee1241624f7e2f85242081el-m1230579714s-w1024_h768.jpg'},
#     {'tags': [{'label': 'porch', 'probability': 0.99280774593353},
#       {'label': 'porch_yard', 'probability': 0.0066093760542572},
#       {'label': 'road_view', 'probability': 0.00026120527763851}],
#      'href': 'https://ap.rdcpix.com/82d0126dfee1241624f7e2f85242081el-m2508429823s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': None,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': True,
#     'is_price_reduced': None,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': False},
#    'community': None,
#    'products': {'brand_name': 'essentials'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2926615207',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True},
#      {'listing_id': '631131403',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '622483339',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None}]},
#    'listing_id': '2926615207',
#    'price_reduced_amount': None,
#    'location': {'address': {'postal_code': '37208',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.807791, 'lat': 36.17543},
#      'city': 'Nashville',
#      'state_code': 'TN',
#      'line': '1617 17th Ave N'},
#     'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1617%2017th%20Ave%20N%2C%20Nashville%2C%20TN%2037208&size=640x480&source=outdoor&signature=eJFXASHzLVm9yWGpclpUt6cY_Bg=',
#     'county': {'fips_code': '47037', 'name': 'Davidson'}},
#    'matterport': False},
#   {'primary_photo': {'href': 'https://ap.rdcpix.com/2ee5e4476ac608818b3a4ef74058104dl-b248904162s-w1024_h768.jpg'},
#    'last_update_date': '2021-03-24T11:16:45Z',
#    'source': {'plan_id': None,
#     'agents': [{'office_name': 'Exit Realty Music City'}],
#     'spec_id': None,
#     'type': 'mls'},
#    'tags': ['central_air',
#     'central_heat',
#     'community_outdoor_space',
#     'single_story',
#     'new_roof',
#     'shopping'],
#    'permalink': '313-Elm-St_Madison_TN_37115_M77848-04307',
#    'status': 'for_sale',
#    'list_date': '2021-02-04T22:05:25Z',
#    'open_houses': None,
#    'description': {'baths_3qtr': None,
#     'year_built': 1935,
#     'sold_price': 35000,
#     'baths_full': 1,
#     'name': None,
#     'baths_half': None,
#     'lot_sqft': 9583,
#     'sqft': 896,
#     'baths': 1,
#     'sub_type': None,
#     'baths_1qtr': None,
#     'garage': None,
#     'stories': 1,
#     'beds': 2,
#     'type': 'single_family'},
#    'branding': [{'name': 'EXIT REALTY MUSIC CITY',
#      'photo': 'https://ap.rdcpix.com/76fb1ff009250d798afd36782bf7cbbco-b1637540070s.jpg',
#      'type': 'Office'}],
#    'list_price': 237999,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '7784804307',
#    'photos': [{'tags': [{'label': 'kitchen', 'probability': 0.98947221040726},
#       {'label': 'laundry_room', 'probability': 0.0092371450737119},
#       {'label': 'bathroom', 'probability': 0.00060551502974704}],
#      'href': 'https://ap.rdcpix.com/2ee5e4476ac608818b3a4ef74058104dl-b248904162s-w1024_h768.jpg'},
#     {'tags': [{'label': 'kitchen', 'probability': 0.99612492322922},
#       {'label': 'laundry_room', 'probability': 0.0033505507744849},
#       {'label': 'bathroom', 'probability': 0.00035924793337472}],
#      'href': 'https://ap.rdcpix.com/2ee5e4476ac608818b3a4ef74058104dl-b2364026406s-w1024_h768.jpg'},
#     {'tags': [{'label': 'kitchen', 'probability': 0.97073727846146},
#       {'label': 'bathroom', 'probability': 0.021955354139209},
#       {'label': 'unknown', 'probability': 0.0064475927501917}],
#      'href': 'https://ap.rdcpix.com/2ee5e4476ac608818b3a4ef74058104dl-b96340056s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.6753066778183},
#       {'label': 'unknown', 'probability': 0.323297560215},
#       {'label': 'dining_room', 'probability': 0.00087469420395792}],
#      'href': 'https://ap.rdcpix.com/2ee5e4476ac608818b3a4ef74058104dl-b2880575075s-w1024_h768.jpg'},
#     {'tags': [{'label': 'unknown', 'probability': 0.97622936964035},
#       {'label': 'bedroom', 'probability': 0.021881502121687},
#       {'label': 'dining_room', 'probability': 0.0013645744184032}],
#      'href': 'https://ap.rdcpix.com/2ee5e4476ac608818b3a4ef74058104dl-b2411158423s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': None,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': None,
#     'is_price_reduced': False,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': False},
#    'community': None,
#    'products': {'brand_name': 'advantage_brand'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2925756752',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True},
#      {'listing_id': '2919797973',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '574088315',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None}]},
#    'listing_id': '2925756752',
#    'price_reduced_amount': 2001,
#    'location': {'address': {'postal_code': '37115',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.706799, 'lat': 36.260745},
#      'city': 'Madison',
#      'state_code': 'TN',
#      'line': '313 Elm St'},
#     'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=313%20Elm%20St%2C%20Madison%2C%20TN%2037115&size=640x480&source=outdoor&signature=2DW0eabrUKlX5y0-YLQ07dwZfio=',
#     'county': {'fips_code': '47037', 'name': 'Davidson'}},
#    'matterport': False},
#   {'primary_photo': {'href': 'https://ap.rdcpix.com/70f5632e5e1e9689a677169668084270l-m2526948340s-w1024_h768.jpg'},
#    'last_update_date': '2021-04-23T15:36:51Z',
#    'source': {'plan_id': None,
#     'agents': [{'office_name': None}],
#     'spec_id': None,
#     'type': 'mls'},
#    'tags': ['central_air',
#     'central_heat',
#     'hardwood_floors',
#     'recreation_facilities',
#     'two_or_more_stories',
#     'garage_1_or_more',
#     'rental_property',
#     'investment_opportunity',
#     'shopping'],
#    'permalink': '1021-Harold-Dr_Nashville_TN_37217_M86321-01333',
#    'status': 'for_sale',
#    'list_date': '2021-01-15T19:33:40Z',
#    'open_houses': None,
#    'description': {'baths_3qtr': None,
#     'year_built': 1973,
#     'sold_price': 62500,
#     'baths_full': 1,
#     'name': None,
#     'baths_half': 1,
#     'lot_sqft': None,
#     'sqft': 992,
#     'baths': 2,
#     'sub_type': 'townhouse',
#     'baths_1qtr': None,
#     'garage': 1,
#     'stories': 2,
#     'beds': 2,
#     'type': 'townhomes'},
#    'branding': [{'name': 'RE/MAX  1ST Choice',
#      'photo': None,
#      'type': 'Office'}],
#    'list_price': 120000,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '8632101333',
#    'photos': [{'tags': [{'label': 'porch_yard',
#        'probability': 0.59758520126343},
#       {'label': 'porch', 'probability': 0.40012145042419},
#       {'label': 'house_view', 'probability': 0.0018141750479117}],
#      'href': 'https://ap.rdcpix.com/70f5632e5e1e9689a677169668084270l-m2526948340s-w1024_h768.jpg'},
#     {'tags': [{'label': 'road_view', 'probability': 0.74853426218033},
#       {'label': 'yard', 'probability': 0.23171409964561},
#       {'label': 'farm_land', 'probability': 0.011151781305671}],
#      'href': 'https://ap.rdcpix.com/70f5632e5e1e9689a677169668084270l-m1048648680s-w1024_h768.jpg'},
#     {'tags': [{'label': 'unknown', 'probability': 0.95841348171234},
#       {'label': 'bedroom', 'probability': 0.037805154919624},
#       {'label': 'kitchen', 'probability': 0.0015384424477816}],
#      'href': 'https://ap.rdcpix.com/70f5632e5e1e9689a677169668084270l-m3781053507s-w1024_h768.jpg'},
#     {'tags': [{'label': 'unknown', 'probability': 0.99763059616089},
#       {'label': 'living_room', 'probability': 0.00093809561803937},
#       {'label': 'porch', 'probability': 0.00093257857952267}],
#      'href': 'https://ap.rdcpix.com/70f5632e5e1e9689a677169668084270l-m1726712766s-w1024_h768.jpg'},
#     {'tags': [{'label': 'bedroom', 'probability': 0.53309226036072},
#       {'label': 'unknown', 'probability': 0.46444526314735},
#       {'label': 'living_room', 'probability': 0.0017506672302261}],
#      'href': 'https://ap.rdcpix.com/70f5632e5e1e9689a677169668084270l-m3819519197s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': None,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': None,
#     'is_price_reduced': True,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': False},
#    'community': None,
#    'products': {'brand_name': 'basic_opt_in'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2925098709',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True},
#      {'listing_id': '2920786217',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '633870487',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '625564535',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '608902219',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '607121291',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '582207523',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '577224919',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '510963203',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None}]},
#    'listing_id': '2925098709',
#    'price_reduced_amount': 5000,
#    'location': {'address': {'postal_code': '37217',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.709919, 'lat': 36.134208},
#      'city': 'Nashville',
#      'state_code': 'TN',
#      'line': '1021 Harold Dr'},
#     'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1021%20Harold%20Dr%2C%20Nashville%2C%20TN%2037217&size=640x480&source=outdoor&signature=7x2qPuLP3bUK69kF7uqBzQyPc1M=',
#     'county': {'fips_code': '47037', 'name': 'Davidson'}},
#    'matterport': False},
#   {'primary_photo': {'href': 'https://ap.rdcpix.com/76453899f23bd39568ae6ee8246439dal-m4103240668s-w1024_h768.jpg'},
#    'last_update_date': '2021-05-01T21:21:35Z',
#    'source': {'plan_id': None,
#     'agents': [{'office_name': 'PARKS'}],
#     'spec_id': None,
#     'type': 'mls'},
#    'tags': ['central_air',
#     'central_heat',
#     'community_outdoor_space',
#     'single_story',
#     'garage_1_or_more',
#     'garage_2_or_more',
#     'garage_3_or_more',
#     'fenced_yard'],
#    'permalink': '3707-John-Mallette-Dr_Nashville_TN_37218_M80305-74421',
#    'status': 'for_sale',
#    'list_date': '2021-04-24T02:34:15Z',
#    'open_houses': None,
#    'description': {'baths_3qtr': None,
#     'year_built': 1934,
#     'sold_price': 45000,
#     'baths_full': 2,
#     'name': None,
#     'baths_half': None,
#     'lot_sqft': 13939,
#     'sqft': 952,
#     'baths': 2,
#     'sub_type': None,
#     'baths_1qtr': None,
#     'garage': 4,
#     'stories': 1,
#     'beds': 2,
#     'type': 'single_family'},
#    'branding': [{'name': 'Parks Realty', 'photo': None, 'type': 'Office'}],
#    'list_price': 205000,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '8030574421',
#    'photos': [{'tags': [{'label': 'house_view',
#        'probability': 0.99746406078339},
#       {'label': 'yard', 'probability': 0.0024026688188314},
#       {'label': 'porch_yard', 'probability': 0.0001207147797686}],
#      'href': 'https://ap.rdcpix.com/76453899f23bd39568ae6ee8246439dal-m4103240668s-w1024_h768.jpg'},
#     {'tags': [{'label': 'porch', 'probability': 0.99975198507309},
#       {'label': 'porch_yard', 'probability': 0.00024706486146897},
#       {'label': 'house_view', 'probability': 7.5390630627226e-07}],
#      'href': 'https://ap.rdcpix.com/76453899f23bd39568ae6ee8246439dal-m4112959177s-w1024_h768.jpg'},
#     {'tags': [{'label': 'unknown', 'probability': 0.98598700761795},
#       {'label': 'bedroom', 'probability': 0.0080019440501928},
#       {'label': 'living_room', 'probability': 0.0040291766636074}],
#      'href': 'https://ap.rdcpix.com/76453899f23bd39568ae6ee8246439dal-m2914678019s-w1024_h768.jpg'},
#     {'tags': [{'label': 'bedroom', 'probability': 0.59004175662994},
#       {'label': 'unknown', 'probability': 0.28075951337814},
#       {'label': 'living_room', 'probability': 0.12901924550533}],
#      'href': 'https://ap.rdcpix.com/76453899f23bd39568ae6ee8246439dal-m1576867962s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.64438992738724},
#       {'label': 'unknown', 'probability': 0.33342838287354},
#       {'label': 'bedroom', 'probability': 0.015905778855085}],
#      'href': 'https://ap.rdcpix.com/76453899f23bd39568ae6ee8246439dal-m1296891765s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': None,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': None,
#     'is_price_reduced': None,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': True},
#    'community': None,
#    'products': {'brand_name': 'essentials'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2928553395',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True},
#      {'listing_id': '2924860943',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None},
#      {'listing_id': '510388759',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None}]},
#    'listing_id': '2928553395',
#    'price_reduced_amount': None,
#    'location': {'address': {'postal_code': '37218',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.839853, 'lat': 36.195427},
#      'city': 'Nashville',
#      'state_code': 'TN',
#      'line': '3707 John Mallette Dr'},
#     'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=3707%20John%20Mallette%20Dr%2C%20Nashville%2C%20TN%2037218&size=640x480&source=outdoor&signature=2PNPjwe8JddfbBoZGRcGMKKlNHM=',
#     'county': {'fips_code': '47037', 'name': 'Davidson'}},
#    'matterport': False},
#   {'primary_photo': {'href': 'https://ap.rdcpix.com/04ed40f43e16869ff043e0d79951a50bl-m2531539123s-w1024_h768.jpg'},
#    'last_update_date': '2021-03-29T08:55:28Z',
#    'source': {'plan_id': None,
#     'agents': [{'office_name': 'Renew Real Estate Services'}],
#     'spec_id': None,
#     'type': 'mls'},
#    'tags': ['central_air',
#     'central_heat',
#     'community_outdoor_space',
#     'dishwasher',
#     'washer_dryer',
#     'basement',
#     'two_or_more_stories',
#     'garage_1_or_more',
#     'garage_2_or_more'],
#    'permalink': '1029-Harold-Dr_Nashville_TN_37217_M73491-08027',
#    'status': 'for_sale',
#    'list_date': '2021-03-04T23:35:34Z',
#    'open_houses': None,
#    'description': {'baths_3qtr': None,
#     'year_built': 1973,
#     'sold_price': 24000,
#     'baths_full': 1,
#     'name': None,
#     'baths_half': 1,
#     'lot_sqft': 436,
#     'sqft': 992,
#     'baths': 2,
#     'sub_type': 'townhouse',
#     'baths_1qtr': None,
#     'garage': 2,
#     'stories': 2,
#     'beds': 2,
#     'type': 'townhomes'},
#    'branding': [{'name': 'Renew Real Estate Services',
#      'photo': None,
#      'type': 'Office'}],
#    'list_price': 149900,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '7349108027',
#    'photos': [{'tags': [{'label': 'living_room',
#        'probability': 0.99977523088455},
#       {'label': 'dining_room', 'probability': 9.2955495347269e-05},
#       {'label': 'house_view', 'probability': 5.1121303840773e-05}],
#      'href': 'https://ap.rdcpix.com/04ed40f43e16869ff043e0d79951a50bl-m2531539123s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.99910151958466},
#       {'label': 'house_view', 'probability': 0.00074732571374625},
#       {'label': 'porch_yard', 'probability': 3.8831116398796e-05}],
#      'href': 'https://ap.rdcpix.com/04ed40f43e16869ff043e0d79951a50bl-m3148807705s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.99988698959351},
#       {'label': 'porch_yard', 'probability': 4.0783437725622e-05},
#       {'label': 'house_view', 'probability': 2.9101141990395e-05}],
#      'href': 'https://ap.rdcpix.com/04ed40f43e16869ff043e0d79951a50bl-m3106730828s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.99981123209},
#       {'label': 'dining_room', 'probability': 0.00011558018741198},
#       {'label': 'house_view', 'probability': 4.2451913031982e-05}],
#      'href': 'https://ap.rdcpix.com/04ed40f43e16869ff043e0d79951a50bl-m2748350671s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.99902105331421},
#       {'label': 'house_view', 'probability': 0.00085833843331784},
#       {'label': 'bedroom', 'probability': 3.7999139749445e-05}],
#      'href': 'https://ap.rdcpix.com/04ed40f43e16869ff043e0d79951a50bl-m3767067593s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': None,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': None,
#     'is_price_reduced': None,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': False},
#    'community': None,
#    'products': {'brand_name': 'basic_opt_in'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2926609583',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True}]},
#    'listing_id': '2926609583',
#    'price_reduced_amount': None,
#    'location': {'address': {'postal_code': '37217',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.709891, 'lat': 36.134049},
#      'city': 'Nashville',
#      'state_code': 'TN',
#      'line': '1029 Harold Dr'},
#     'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1029%20Harold%20Dr%2C%20Nashville%2C%20TN%2037217&size=640x480&source=outdoor&signature=oN8j8ocFcW8XUPM7p5HIBboH33A=',
#     'county': {'fips_code': '47037', 'name': 'Davidson'}},
#    'matterport': False},
#   {'primary_photo': {'href': 'https://ap.rdcpix.com/63f96b04c93ef8b55b0af610fec7c431l-m3384610144s-w1024_h768.jpg'},
#    'last_update_date': '2021-01-22T13:10:33Z',
#    'source': {'plan_id': None,
#     'agents': [{'office_name': None}],
#     'spec_id': None,
#     'type': 'mls'},
#    'tags': ['central_air',
#     'central_heat',
#     'community_gym',
#     'community_outdoor_space',
#     'dishwasher',
#     'hardwood_floors',
#     'laundry_room',
#     'recreation_facilities',
#     'community_swimming_pool',
#     'basement',
#     'two_or_more_stories',
#     'garage_1_or_more',
#     'rental_property',
#     'shopping'],
#    'permalink': '3415-West-End-Ave-Apt-701_Nashville_TN_37203_M74231-44540',
#    'status': 'for_sale',
#    'list_date': '2021-01-22T04:03:19Z',
#    'open_houses': None,
#    'description': {'baths_3qtr': None,
#     'year_built': 1958,
#     'sold_price': None,
#     'baths_full': 1,
#     'name': None,
#     'baths_half': 1,
#     'lot_sqft': None,
#     'sqft': 816,
#     'baths': 2,
#     'sub_type': 'condo',
#     'baths_1qtr': None,
#     'garage': 1,
#     'stories': 11,
#     'beds': 1,
#     'type': 'condos'},
#    'branding': [{'name': 'Hodges and Fooshee Realty Inc.',
#      'photo': None,
#      'type': 'Office'}],
#    'list_price': 220000,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '7423144540',
#    'photos': [{'tags': [{'label': 'living_room',
#        'probability': 0.99919050931931},
#       {'label': 'house_view', 'probability': 0.00044877611799166},
#       {'label': 'dining_room', 'probability': 0.00029064554837532}],
#      'href': 'https://ap.rdcpix.com/63f96b04c93ef8b55b0af610fec7c431l-m3384610144s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.99939107894897},
#       {'label': 'house_view', 'probability': 0.00021381159604061},
#       {'label': 'bedroom', 'probability': 0.00016315348329954}],
#      'href': 'https://ap.rdcpix.com/63f96b04c93ef8b55b0af610fec7c431l-m1294848034s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.86010718345642},
#       {'label': 'bedroom', 'probability': 0.12086771428585},
#       {'label': 'unknown', 'probability': 0.01749949529767}],
#      'href': 'https://ap.rdcpix.com/63f96b04c93ef8b55b0af610fec7c431l-m1191392935s-w1024_h768.jpg'},
#     {'tags': [{'label': 'laundry_room', 'probability': 0.94095748662949},
#       {'label': 'unknown', 'probability': 0.021667018532753},
#       {'label': 'living_room', 'probability': 0.014705223031342}],
#      'href': 'https://ap.rdcpix.com/63f96b04c93ef8b55b0af610fec7c431l-m3533268328s-w1024_h768.jpg'},
#     {'tags': [{'label': 'dining_room', 'probability': 0.340162307024},
#       {'label': 'unknown', 'probability': 0.31088355183601},
#       {'label': 'living_room', 'probability': 0.27236831188202}],
#      'href': 'https://ap.rdcpix.com/63f96b04c93ef8b55b0af610fec7c431l-m330814590s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': None,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': None,
#     'is_price_reduced': None,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': False},
#    'community': None,
#    'products': {'brand_name': 'basic_opt_in'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2925292235',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True}]},
#    'listing_id': '2925292235',
#    'price_reduced_amount': None,
#    'location': {'address': {'postal_code': '37203',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.819537, 'lat': 36.138195},
#      'city': 'Nashville',
#      'state_code': 'TN',
#      'line': '3415 West End Ave Apt 701A'},
# ...
#     'baths_half': None,
#     'lot_sqft': 17424,
#     'sqft': 969,
#     'baths': 1,
#     'sub_type': 'condo',
#     'baths_1qtr': None,
#     'garage': 1,
#     'stories': 4,
#     'beds': 1,
#     'type': 'condos'},
#    'branding': [{'name': 'Compass Tennessee, LLC dba Compass RE',
#      'photo': None,
#      'type': 'Office'}],
#    'list_price': 410900,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '9139020346',
#    'photos': [{'tags': [{'label': 'dining_room',
#        'probability': 0.99477154016495},
#       {'label': 'living_room', 'probability': 0.0026688941288739},
#       {'label': 'unknown', 'probability': 0.0023695274721831}],
#      'href': 'https://ap.rdcpix.com/4777e1ad6c19403c86c23953b3d2305fl-m2000047907s-w1024_h768.jpg'},
#     {'tags': [{'label': 'dining_room', 'probability': 0.83785116672516},
#       {'label': 'living_room', 'probability': 0.086469225585461},
#       {'label': 'unknown', 'probability': 0.051168080419302}],
#      'href': 'https://ap.rdcpix.com/4777e1ad6c19403c86c23953b3d2305fl-m1742136018s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.49510058760643},
#       {'label': 'dining_room', 'probability': 0.42727988958359},
#       {'label': 'bedroom', 'probability': 0.047102745622396}],
#      'href': 'https://ap.rdcpix.com/4777e1ad6c19403c86c23953b3d2305fl-m1323112745s-w1024_h768.jpg'},
#     {'tags': [{'label': 'bedroom', 'probability': 0.99999737739563},
#       {'label': 'laundry_room', 'probability': 1.5434792430824e-06},
#       {'label': 'floor_plan', 'probability': 8.7107338231363e-07}],
#      'href': 'https://ap.rdcpix.com/4777e1ad6c19403c86c23953b3d2305fl-m214531230s-w1024_h768.jpg'},
#     {'tags': [{'label': 'bathroom', 'probability': 0.99845886230469},
#       {'label': 'laundry_room', 'probability': 0.0012317590881139},
#       {'label': 'unknown', 'probability': 0.00020402112568263}],
#      'href': 'https://ap.rdcpix.com/4777e1ad6c19403c86c23953b3d2305fl-m3485838828s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': None,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': None,
#     'is_price_reduced': None,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': False},
#    'community': None,
#    'products': {'brand_name': 'essentials'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2926104097',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True},
#      {'listing_id': '2917843707',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None}]},
#    'listing_id': '2926104097',
#    'price_reduced_amount': None,
#    'location': {'address': {'postal_code': '37203',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.77969904, 'lat': 36.14386709},
#      'city': 'Nashville',
#      'state_code': 'TN',
#      'line': '806 Olympic St Ste 406'},
#     'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=806%20Olympic%20St%20Ste%20406%2C%20Nashville%2C%20TN%2037203&size=640x480&source=outdoor&signature=5DkTqRyak9M8jiD4-R-gK3sEYQQ=',
#     'county': {'fips_code': '47037', 'name': 'Davidson'}},
#    'matterport': False},
#   {'primary_photo': {'href': 'https://ap.rdcpix.com/0f0dcb28f986dd198892f62b96376412l-m2061939674s-w1024_h768.jpg'},
#    'last_update_date': '2021-04-08T08:02:12Z',
#    'source': {'plan_id': None,
#     'agents': [{'office_name': None}],
#     'spec_id': None,
#     'type': 'mls'},
#    'tags': ['central_air',
#     'central_heat',
#     'city_view',
#     'community_outdoor_space',
#     'dishwasher',
#     'energy_efficient',
#     'hardwood_floors',
#     'view',
#     'basement',
#     'two_or_more_stories',
#     'garage_1_or_more',
#     'floor_plan',
#     'smart_homes'],
#    'permalink': '1125-10th-Ave-N-Apt-507_Nashville_TN_37208_M98205-79578',
#    'status': 'for_sale',
#    'list_date': '2021-04-08T15:35:07Z',
#    'open_houses': [{'start_date': '2021-05-06T11:00:00',
#      'description': None,
#      'end_date': '2021-05-06T14:00:00',
#      'dst': True,
#      'time_zone': 'CST'},
#     {'start_date': '2021-05-08T12:00:00',
#      'description': None,
#      'end_date': '2021-05-08T16:00:00',
#      'dst': True,
#      'time_zone': 'CST'},
#     {'start_date': '2021-05-09T12:00:00',
#      'description': None,
#      'end_date': '2021-05-09T16:00:00',
#      'dst': True,
#      'time_zone': 'CST'}],
#    'description': {'baths_3qtr': None,
#     'year_built': 2021,
#     'sold_price': None,
#     'baths_full': 1,
#     'name': None,
#     'baths_half': None,
#     'lot_sqft': 436,
#     'sqft': 784,
#     'baths': 1,
#     'sub_type': 'condo',
#     'baths_1qtr': None,
#     'garage': 1,
#     'stories': 5,
#     'beds': 1,
#     'type': 'condos'},
#    'branding': [{'name': 'Compass Tennessee, Llc',
#      'photo': None,
#      'type': 'Office'}],
#    'list_price': 399900,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '9820579578',
#    'photos': [{'tags': [{'label': 'house_view',
#        'probability': 0.99999821186066},
#       {'label': 'road_view', 'probability': 1.8133355297323e-06},
#       {'label': 'water_front', 'probability': 1.7863685641828e-08}],
#      'href': 'https://ap.rdcpix.com/0f0dcb28f986dd198892f62b96376412l-m2061939674s-w1024_h768.jpg'},
#     {'tags': [{'label': 'road_view', 'probability': 0.32267910242081},
#       {'label': 'house_view', 'probability': 0.26989179849625},
#       {'label': 'unknown', 'probability': 0.22306032478809}],
#      'href': 'https://ap.rdcpix.com/0f0dcb28f986dd198892f62b96376412l-m1522726216s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.99930381774902},
#       {'label': 'porch_yard', 'probability': 0.00053534522885457},
#       {'label': 'house_view', 'probability': 0.0001101759262383}],
#      'href': 'https://ap.rdcpix.com/0f0dcb28f986dd198892f62b96376412l-m1115801626s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.99895656108856},
#       {'label': 'dining_room', 'probability': 0.00053287053015083},
#       {'label': 'unknown', 'probability': 0.00027615181170404}],
#      'href': 'https://ap.rdcpix.com/0f0dcb28f986dd198892f62b96376412l-m4012756304s-w1024_h768.jpg'},
#     {'tags': [{'label': 'laundry_room', 'probability': 0.95987075567245},
#       {'label': 'unknown', 'probability': 0.033696077764034},
#       {'label': 'bathroom', 'probability': 0.0061019845306873}],
#      'href': 'https://ap.rdcpix.com/0f0dcb28f986dd198892f62b96376412l-m2706535219s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': None,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': None,
#     'is_price_reduced': None,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': False},
#    'community': None,
#    'products': {'brand_name': 'essentials'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2927897457',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True},
#      {'listing_id': '2926110410',
#       'listing_key': None,
#       'status': 'off_market',
#       'primary': None}]},
#    'listing_id': '2927897457',
#    'price_reduced_amount': None,
#    'location': {'address': {'postal_code': '37208',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.795489, 'lat': 36.173101},
#      'city': 'Nashville',
#      'state_code': 'TN',
#      'line': '1125 10th Ave N Apt 507'},
#     'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1125%2010th%20Ave%20N%20Apt%20507%2C%20Nashville%2C%20TN%2037208&size=640x480&source=outdoor&signature=F8mGUblYi7h6gYFU7lQ7joH3knI=',
#     'county': {'fips_code': '47037', 'name': 'Davidson'}},
#    'matterport': False},
#   {'primary_photo': {'href': 'https://ap.rdcpix.com/11a1dd1f5d2ed587ae2e8b3d9b06e50al-m14567333s-w1024_h768.jpg'},
#    'last_update_date': '2021-04-08T08:00:26Z',
#    'source': {'plan_id': None,
#     'agents': [{'office_name': None}],
#     'spec_id': None,
#     'type': 'mls'},
#    'tags': ['central_air',
#     'central_heat',
#     'city_view',
#     'community_outdoor_space',
#     'dishwasher',
#     'energy_efficient',
#     'hardwood_floors',
#     'view',
#     'basement',
#     'two_or_more_stories',
#     'garage_1_or_more',
#     'floor_plan',
#     'smart_homes'],
#    'permalink': '1125-10th-Ave-N-Apt-303_Nashville_TN_37208_M95366-37064',
#    'status': 'for_sale',
#    'list_date': '2021-04-08T15:35:07Z',
#    'open_houses': [{'start_date': '2021-05-06T11:00:00',
#      'description': None,
#      'end_date': '2021-05-06T14:00:00',
#      'dst': True,
#      'time_zone': 'CST'},
#     {'start_date': '2021-05-08T12:00:00',
#      'description': None,
#      'end_date': '2021-05-08T16:00:00',
#      'dst': True,
#      'time_zone': 'CST'},
#     {'start_date': '2021-05-09T12:00:00',
#      'description': None,
#      'end_date': '2021-05-09T16:00:00',
#      'dst': True,
#      'time_zone': 'CST'}],
#    'description': {'baths_3qtr': None,
#     'year_built': 2021,
#     'sold_price': None,
#     'baths_full': 1,
#     'name': None,
#     'baths_half': None,
#     'lot_sqft': 436,
#     'sqft': 784,
#     'baths': 1,
#     'sub_type': 'condo',
#     'baths_1qtr': None,
#     'garage': 1,
#     'stories': 5,
#     'beds': 1,
#     'type': 'condos'},
#    'branding': [{'name': 'Compass Tennessee, Llc',
#      'photo': None,
#      'type': 'Office'}],
#    'list_price': 359900,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '9536637064',
#    'photos': [{'tags': [{'label': 'house_view',
#        'probability': 0.99999797344208},
#       {'label': 'road_view', 'probability': 2.0310251329647e-06},
#       {'label': 'water_front', 'probability': 1.664363757925e-08}],
#      'href': 'https://ap.rdcpix.com/11a1dd1f5d2ed587ae2e8b3d9b06e50al-m14567333s-w1024_h768.jpg'},
#     {'tags': [{'label': 'road_view', 'probability': 0.31820860505104},
#       {'label': 'house_view', 'probability': 0.27248302102089},
#       {'label': 'unknown', 'probability': 0.22658316791058}],
#      'href': 'https://ap.rdcpix.com/11a1dd1f5d2ed587ae2e8b3d9b06e50al-m2079426051s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.99948161840439},
#       {'label': 'porch_yard', 'probability': 0.00038689482607879},
#       {'label': 'house_view', 'probability': 8.851605525706e-05}],
#      'href': 'https://ap.rdcpix.com/11a1dd1f5d2ed587ae2e8b3d9b06e50al-m3185205722s-w1024_h768.jpg'},
#     {'tags': [{'label': 'living_room', 'probability': 0.99902093410492},
#       {'label': 'dining_room', 'probability': 0.00047737677232362},
#       {'label': 'unknown', 'probability': 0.00027323106769472}],
#      'href': 'https://ap.rdcpix.com/11a1dd1f5d2ed587ae2e8b3d9b06e50al-m1067911914s-w1024_h768.jpg'},
#     {'tags': [{'label': 'laundry_room', 'probability': 0.96456879377365},
#       {'label': 'unknown', 'probability': 0.030029281973839},
#       {'label': 'bathroom', 'probability': 0.0051243151538074}],
#      'href': 'https://ap.rdcpix.com/11a1dd1f5d2ed587ae2e8b3d9b06e50al-m991662100s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': None,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': None,
#     'is_price_reduced': None,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': False},
#    'community': None,
#    'products': {'brand_name': 'essentials'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2927897456',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True}]},
#    'listing_id': '2927897456',
#    'price_reduced_amount': None,
#    'location': {'address': {'postal_code': '37208',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.79556952, 'lat': 36.173153879},
#      'city': 'Nashville',
#      'state_code': 'TN',
#      'line': '1125 10th Ave N Apt 303'},
#     'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1125%2010th%20Ave%20N%20Apt%20303%2C%20Nashville%2C%20TN%2037208&size=640x480&source=outdoor&signature=kPgCKKrYxRENvGiYCd2YvrP5TP4=',
#     'county': {'fips_code': '47037', 'name': 'Davidson'}},
#    'matterport': False},
#   {'primary_photo': {'href': 'https://ap.rdcpix.com/e0557ac3838964b1bd7a1bdca9de12b7l-m2310607908s-w1024_h768.jpg'},
#    'last_update_date': '2021-04-09T12:44:40Z',
#    'source': {'plan_id': None,
#     'agents': [{'office_name': 'VILLAGE'}],
#     'spec_id': None,
#     'type': 'mls'},
#    'tags': ['central_air',
#     'central_heat',
#     'community_outdoor_space',
#     'hardwood_floors',
#     'new_construction',
#     'basement',
#     'single_story',
#     'garage_1_or_more',
#     'rental_property'],
#    'permalink': '303-31st-Ave-N-513_Nashville_TN_37203_M98155-76074',
#    'status': 'for_sale',
#    'list_date': '2021-04-08T23:04:50Z',
#    'open_houses': None,
#    'description': {'baths_3qtr': None,
#     'year_built': 2022,
#     'sold_price': None,
#     'baths_full': 2,
#     'name': None,
#     'baths_half': None,
#     'lot_sqft': None,
#     'sqft': 868,
#     'baths': 2,
#     'sub_type': 'condo',
#     'baths_1qtr': None,
#     'garage': 1,
#     'stories': 1,
#     'beds': 2,
#     'type': 'condos'},
#    'branding': [{'name': 'VILLAGE', 'photo': None, 'type': 'Office'}],
#    'list_price': 479900,
#    'lead_attributes': {'show_contact_an_agent': True},
#    'property_id': '9815576074',
#    'photos': [{'tags': [{'label': 'house_view',
#        'probability': 0.99999988079071},
#       {'label': 'floor_plan', 'probability': 1.3286275191149e-07},
#       {'label': 'water_front', 'probability': 9.3470680084806e-09}],
#      'href': 'https://ap.rdcpix.com/e0557ac3838964b1bd7a1bdca9de12b7l-m2310607908s-w1024_h768.jpg'},
#     {'tags': [{'label': 'yard', 'probability': 0.66728830337524},
#       {'label': 'porch_yard', 'probability': 0.31910076737404},
#       {'label': 'unknown', 'probability': 0.0050003374926746}],
#      'href': 'https://ap.rdcpix.com/e0557ac3838964b1bd7a1bdca9de12b7l-m634837276s-w1024_h768.jpg'},
#     {'tags': [{'label': 'house_view', 'probability': 0.99999392032623},
#       {'label': 'living_room', 'probability': 5.0712724259938e-06},
#       {'label': 'floor_plan', 'probability': 5.9017412468165e-07}],
#      'href': 'https://ap.rdcpix.com/e0557ac3838964b1bd7a1bdca9de12b7l-m2980739939s-w1024_h768.jpg'},
#     {'tags': [{'label': 'floor_plan', 'probability': 0.99987745285034},
#       {'label': 'unknown', 'probability': 0.00012201921344968},
#       {'label': 'house_view', 'probability': 3.070232992286e-07}],
#      'href': 'https://ap.rdcpix.com/e0557ac3838964b1bd7a1bdca9de12b7l-m2308922791s-w1024_h768.jpg'},
#     {'tags': [{'label': 'floor_plan', 'probability': 0.74124610424042},
#       {'label': 'unknown', 'probability': 0.23248548805714},
#       {'label': 'laundry_room', 'probability': 0.024842312559485}],
#      'href': 'https://ap.rdcpix.com/e0557ac3838964b1bd7a1bdca9de12b7l-m3523041573s-w1024_h768.jpg'}],
#    'flags': {'is_new_construction': True,
#     'is_for_rent': None,
#     'is_subdivision': None,
#     'is_contingent': None,
#     'is_price_reduced': None,
#     'is_pending': None,
#     'is_foreclosure': None,
#     'is_plan': None,
#     'is_coming_soon': None,
#     'is_new_listing': False},
#    'community': None,
#    'products': {'brand_name': 'essentials'},
#    'virtual_tours': None,
#    'other_listings': {'rdc': [{'listing_id': '2927930061',
#       'listing_key': None,
#       'status': 'for_sale',
#       'primary': True}]},
#    'listing_id': '2927930061',
#    'price_reduced_amount': None,
#    'location': {'address': {'postal_code': '37203',
#      'state': 'Tennessee',
#      'coordinate': {'lon': -86.81637997, 'lat': 36.148201984},
#      'city': 'Nashville',
#      'state_code': 'TN',
#      'line': '303 31st Ave N Unit 513'},
#     'street_view_url': 'https://maps.googleapis.com/maps/api/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=303%2031st%20Ave%20N%20Unit%20513%2C%20Nashville%2C%20TN%2037203&size=640x480&source=outdoor&signature=pdrvmMT4bONEPhS5JGYXCI7DRqc=',
#     'county': {'fips_code': '47037', 'name': 'Davidson'}},
#    'matterport': False}]}

# %%
df.columns
# Out:
# Index(['last_update_date', 'tags', 'permalink', 'status', 'list_date',
#        'open_houses', 'branding', 'list_price', 'property_id', 'photos',
#        'community', 'virtual_tours', 'listing_id', 'price_reduced_amount',
#        'matterport', 'primary_photo.href', 'source.plan_id', 'source.agents',
#        'source.spec_id', 'source.type', 'description.baths_3qtr',
#        'description.year_built', 'description.sold_price',
#        'description.baths_full', 'description.name', 'description.baths_half',
#        'description.lot_sqft', 'description.sqft', 'description.baths',
#        'description.sub_type', 'description.baths_1qtr', 'description.garage',
#        'description.stories', 'description.beds', 'description.type',
#        'lead_attributes.show_contact_an_agent', 'flags.is_new_construction',
#        'flags.is_for_rent', 'flags.is_subdivision', 'flags.is_contingent',
#        'flags.is_price_reduced', 'flags.is_pending', 'flags.is_foreclosure',
#        'flags.is_plan', 'flags.is_coming_soon', 'flags.is_new_listing',
#        'products.brand_name', 'other_listings.rdc',
#        'location.address.postal_code', 'location.address.state',
#        'location.address.coordinate.lon', 'location.address.coordinate.lat',
#        'location.address.city', 'location.address.state_code',
#        'location.address.line', 'location.street_view_url',
#        'location.county.fips_code', 'location.county.name', 'primary_photo',
#        'other_listings', 'community.advertisers',
#        'community.description.name'],
#       dtype='object')

# %%
df['description.sold_price'].count()
# Out:
# 938

# %%
pd.set_option("display.max_rows", 5, "display.max_columns", None)
df = df.drop(['branding','photos', 'open_houses', 'virtual_tours', 'source.plan_id', 'source.agents', 'source.spec_id', 'lead_attributes.show_contact_an_agent','flags.is_coming_soon', 'matterport', 'source.plan_id','flags.is_coming_soon', 'products.brand_name'], axis=1)
