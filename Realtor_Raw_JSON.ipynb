# %%
import requests

url = "https://realtor-com-real-estate.p.rapidapi.com/for-sale"

querystring = {"city":"Nashville","state_code":"TN","limit":"200","offset":"0"}

headers = {
    'x-rapidapi-key': "KEY REMOVED",
    'x-rapidapi-host': "realtor-com-real-estate.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"status":200,"data":{"total":2333,"count":200,"results":[{"primary_photo":{"href":"https:\/\/ap.rdcpix.com\/f44c6589638c4c23fcde879a06af2db8l-m1224733601s-w1024_h768.jpg"},"last_update_date":"2021-04-23T10:02:40Z","source":{"plan_id":null,"agents":[{"office_name":"Summit Realty Group"}],"spec_id":null,"type":"mls"},"tags":["community_outdoor_space","corner_lot","hardwood_floors","basement","single_story","fenced_yard","big_lot","lake"],"permalink":"1601-Overton-St_Old-Hickory_TN_37138_M80331-30027","status":"for_sale","list_date":"2021-04-23T17:05:21Z","open_houses":null,"description":{"baths_3qtr":null,"year_built":1934,"sold_price":null,"baths_full":1,"name":null,"baths_half":null,"lot_sqft":13939,"sqft":1145,"baths":1,"sub_type":null,"baths_1qtr":null,"garage":null,"stories":1,"beds":2,"type":"single_family"},"branding":[{"name":"Summit Realty Group","photo":null,"type":"Office"}],"list_price":160000,"lead_attributes":{"show_contact_an_agent":true},"property_id":"8033130027","photos":[{"tags":[{"label":"house_view","probability":0.99999964237213},{"label":"porch_yard","probability":2.4721313707232e-07},{"label":"porch","probability":6.032758648189e-08}],"href":"https:\/\/ap.rdcpix.com\/f44c6589638c4c23fcde879a06af2db8l-m1224733601s-w1024_h768.jpg"}],"flags":{"is_new_construction":null,"is_for_rent":null,"is_subdivision":null,"is_contingent":null,"is_price_reduced":null,"is_pending":null,"is_foreclosure":null,"is_plan":null,"is_coming_soon":null,"is_new_listing":true},"community":null,"products":{"brand_name":"basic_opt_in"},"virtual_tours":null,"other_listings":{"rdc":[{"listing_id":"2928519808","listing_key":null,"status":"for_sale","primary":true}]},"listing_id":"2928519808","price_reduced_amount":null,"location":{"address":{"postal_code":"37138","state":"Tennessee","coordinate":{"lon":-86.643896,"lat":36.254095},"city":"Old Hickory","state_code":"TN","line":"1601 Overton St"},"street_view_url":"https:\/\/maps.googleapis.com\/maps\/api\/streetview?channel=rdc-streetview&client=gme-movesalesinc&location=1601%20Overton%20St%2C%20Old%20Hickory%2C%20TN%2037138&size=640x480&source=outdoor&signature=Lj9Rlt3KepL1Xh5_tojR0nsuHKA=","county":{"fips_code":"47037","name":"Davidson"}},"matterport":false},{"primary_photo":{"href":"https:\/\/ap.rdcpix.com\/2308e283f9d48065b00ea2c1d9ddb240l-m2730228435s-w1024_h768.jpg"},"last_update_date":"2021-04-28T08:15:40Z","source":{"plan_id":null,"agents":[{"office_name":null}],"spec_id":null,"type":"mls"},"tags":["central_heat","community_outdoor_space","dishwasher","fireplace","single_story","garage_1_or_more","garage_2_or_more","open_house"],"permalink":"1340-Quail-Valley-Rd_Nashville_TN_37214_M73898-94485","status":"for_sale","list_date":"2021-04-23T03:05:52Z","open_houses":null,"description":{"baths_3qtr":null,"year_built":1985,"sold_price":101800,"baths_full":2,"name":null,"baths_half":null,"lot_sqft":871,"sqft":1044,"baths":2,"sub_type":null,"baths_1qtr":null,"garage":2,"stories":1,"beds":3,"type":"single_family"},"branding":[{"name":"Exp Realty","photo":null,"type":"Office"}],"list_price":189910,"lead_attributes":{"show_contact_an_agent":true},"property_id":"7389894485","photos":[{"tags":[{"label":"porch","probability":0.97179520130157},{"label":"porch_yard","probability":0.028174798935652},{"label":"road_view","probability":1.6050002159318e-05}],"href":"https:\/\/ap.rdcpix.com\/2308e283f9d48065b00ea2c1d9ddb240l-m2730228435s-w1024_h768.jpg"},{"tags":[{"label":"house_view","probability":0.77169221639633},{"label":"porch_yard","probability":0.21031142771244},{"label":"porch","probability":0.015830509364605}],"href":"https:\/\/ap.rdcpix.com\/2308e283f9d48065b00ea2c1d9ddb240l-m289523373s-w1024_h768.jpg"},{"tags":[{"label":"kitchen","probability":0.99999845027924},{"label":"laundry_room","probability":9.8190218977834e-07},{"label":"house_view","probability":2.5282949422945e-07}],"href":"https:\/\/ap.rdcpix.com\/2308e283f9d48065b00ea2c1d9ddb240l-m2568931600s-w1024_h768.jpg"},{"tags":[{"label":"k ...
